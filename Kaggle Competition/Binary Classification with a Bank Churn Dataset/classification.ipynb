# %% [markdown]
# # Binary Classification with a Bank Churn Dataset
# ***

# %%
# Importing all the dependencies
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier, Pool
from catboost.utils import eval_metric

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
sample = pd.read_csv('sample_submission.csv')

# %% [markdown]
# ### Exploratory Data Analysis
# ***

# %%
train_data
# Out:
#             id  CustomerId  ... EstimatedSalary  Exited
# 0            0    15674932  ...       181449.97       0
# 1            1    15749177  ...        49503.50       0
# 2            2    15694510  ...       184866.69       0
# 3            3    15741417  ...        84560.88       0
# 4            4    15766172  ...        15068.83       0
# ...        ...         ...  ...             ...     ...
# 165029  165029    15667085  ...       131834.75       0
# 165030  165030    15665521  ...       131834.45       0
# 165031  165031    15664752  ...       127429.56       0
# 165032  165032    15689614  ...        71173.03       0
# 165033  165033    15732798  ...        61581.79       1
#
# [165034 rows x 14 columns]

# %%
train_data['Exited'].unique()
# Out:
# array([0, 1])

# %%
sample
# Out:
#             id  Exited
# 0       165034     0.5
# 1       165035     0.5
# 2       165036     0.5
# 3       165037     0.5
# 4       165038     0.5
# ...        ...     ...
# 110018  275052     0.5
# 110019  275053     0.5
# 110020  275054     0.5
# 110021  275055     0.5
# 110022  275056     0.5
#
# [110023 rows x 2 columns]

# %%
# Remove CustomerID and Surname as it does not add value to our data
for ds in [train_data, test_data]:
    ds.drop(['CustomerId', 'Surname', "id"], axis=1, inplace=True)

# %%
test_data
# Out:
#         CreditScore Geography  ... IsActiveMember  EstimatedSalary
# 0               586    France  ...            1.0        160976.75
# 1               683    France  ...            0.0         72549.27
# 2               656    France  ...            0.0        138882.09
# 3               681    France  ...            0.0        113931.57
# 4               752   Germany  ...            0.0        139431.00
# ...             ...       ...  ...            ...              ...
# 110018          570     Spain  ...            1.0        148087.62
# 110019          575    France  ...            1.0         42181.68
# 110020          712    France  ...            0.0         16287.38
# 110021          709    France  ...            1.0        158816.58
# 110022          621    France  ...            0.0         24210.56
#
# [110023 rows x 10 columns]

# %%
train_data
# Out:
#         CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0               668    France    Male  ...             0.0        181449.97       0
# 1               627    France    Male  ...             1.0         49503.50       0
# 2               678    France    Male  ...             0.0        184866.69       0
# 3               581    France    Male  ...             1.0         84560.88       0
# 4               716     Spain    Male  ...             1.0         15068.83       0
# ...             ...       ...     ...  ...             ...              ...     ...
# 165029          667     Spain  Female  ...             1.0        131834.75       0
# 165030          792    France    Male  ...             0.0        131834.45       0
# 165031          565    France    Male  ...             1.0        127429.56       0
# 165032          554     Spain  Female  ...             1.0         71173.03       0
# 165033          850    France    Male  ...             0.0         61581.79       1
#
# [165034 rows x 11 columns]

# %%
y = train_data['Exited']
x = train_data.drop(['Exited'], axis=1)

# %%
x.head()
# Out:
#    CreditScore Geography Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          668    France   Male  ...        1.0             0.0        181449.97
# 1          627    France   Male  ...        1.0             1.0         49503.50
# 2          678    France   Male  ...        1.0             0.0        184866.69
# 3          581    France   Male  ...        1.0             1.0         84560.88
# 4          716     Spain   Male  ...        1.0             1.0         15068.83
#
# [5 rows x 10 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
label_encoder = LabelEncoder()
for cat in ['Geography','Gender']:
    x[cat] = label_encoder.fit_transform(x[cat])
x.head()
# Out:
#    CreditScore  Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          668          0       1  ...        1.0             0.0        181449.97
# 1          627          0       1  ...        1.0             1.0         49503.50
# 2          678          0       1  ...        1.0             0.0        184866.69
# 3          581          0       1  ...        1.0             1.0         84560.88
# 4          716          2       1  ...        1.0             1.0         15068.83
#
# [5 rows x 10 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, stratify=y)

# %%
cols = x_train
features = np.where(cols.dtypes != np.float64)[0]
train_pool = Pool(x_train, y_train, cat_features=features)
test_pool = Pool(x_test, y_test, cat_features=features)

# %%
model = CatBoostClassifier(eval_metric="AUC", learning_rate=0.03, iterations=1940)
model.fit(train_pool, eval_set=test_pool, verbose=500)
y_pred = model.predict_proba(x_test)[:,1]
auc = roc_auc_score(y_test, y_pred)
print("AUC is: ",auc)
# Out:
# 0:	test: 0.8729404	best: 0.8729404 (0)	total: 53.1ms	remaining: 1m 43s
# 500:	test: 0.8897273	best: 0.8897273 (500)	total: 35.5s	remaining: 1m 42s
# 1000:	test: 0.8901859	best: 0.8901975 (983)	total: 1m 13s	remaining: 1m 8s
# 1500:	test: 0.8903832	best: 0.8903875 (1496)	total: 1m 46s	remaining: 31.2s
# 1939:	test: 0.8905012	best: 0.8905012 (1939)	total: 2m 14s	remaining: 0us
#
# bestTest = 0.8905012259
# bestIteration = 1939
#
# AUC is:  0.8905012258512688

# %%
test_id = pd.read_csv('./test.csv')
submission_df = pd.DataFrame({'id':test_id['id'], 'Exited':model.predict_proba(test_data)[:,1]})
submission_df.head(5)
# Out:
#        id    Exited
# 0  165034  0.024825
# 1  165035  0.616963
# 2  165036  0.041072
# 3  165037  0.248989
# 4  165038  0.413466

# %%
submission_df.to_csv('submission.csv', index=False)
